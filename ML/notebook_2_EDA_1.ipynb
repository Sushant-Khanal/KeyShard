# %% [markdown]
# # reading dataset

# %%
import pandas as pd
import re

# %%
df = pd.read_csv(r"E:\major_project\dataset\datasets\sampled_df.csv")

# %%
df
# Out:
#                     password  length bucket  strength
# 0                       agus       4    0-4       1.0
# 1                       roar       4    0-4       1.0
# 2                       malz       4    0-4       1.0
# 3                       cuba       4    0-4       1.0
# 4                       pcms       4    0-4       1.0
# ...                      ...     ...    ...       ...
# 299995     changepassword___      17    17+       3.0
# 299996    stupidmotherfucker      18    17+       2.0
# 299997     luistekelounresto      17    17+       4.0
# 299998  themontles@yahoo.com      20    17+       4.0
# 299999     secilandralph7497      17    17+       4.0
#
# [300000 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300000 entries, 0 to 299999
# Data columns (total 4 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   password  299997 non-null  object
#  1   length    300000 non-null  int64
#  2   bucket    300000 non-null  object
#  3   strength  299995 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 9.2+ MB

# %%
df.describe()
# Out:
#               length       strength
# count  300000.000000  299995.000000
# mean        9.146027       2.068358
# std         3.312255       1.010141
# min         1.000000       0.000000
# 25%         7.000000       1.000000
# 50%         8.500000       2.000000
# 75%        10.000000       3.000000
# max        96.000000       4.000000

# %% [markdown]
# while cleaning the data sets, we have to look for duplicates, NaN values, empty value, unredeable characters, and valid length fo passwords.

# %% [markdown]
# # removing duplicates and empty passwords

# %%
#checking for duplicates
df.duplicated().sum()
# Out:
# 27

# %%
df[df.duplicated()]
# Out:
#      password  length bucket  strength
# 967      stfu       4    0-4       1.0
# 1002     bill       4    0-4       0.0
# 4506     jack       4    0-4       0.0
# 5849      333       3    0-4       0.0
# 6007        7       1    0-4       0.0
# 6068     love       4    0-4       0.0
# 6359     jonh       4    0-4       1.0
# 6543      NaN       3    0-4       0.0
# 7639     fuck       4    0-4       0.0
# 7933      123       3    0-4       0.0
# 7940     love       4    0-4       0.0
# 7970     cunt       4    0-4       0.0
# 8051       no       2    0-4       0.0
# 8240     gian       4    0-4       1.0
# 8528     sexy       4    0-4       0.0
# 8574      333       3    0-4       0.0
# 8745      NaN       3    0-4       0.0
# 8969     nile       4    0-4       1.0
# 8983     hiya       4    0-4       1.0
# 9209     lolo       4    0-4       0.0
# 9279     azul       4    0-4       1.0
# 9288     mark       4    0-4       0.0
# 9338     hugo       4    0-4       0.0
# 9356      000       3    0-4       0.0
# 9434      314       3    0-4       0.0
# 9503     andy       4    0-4       0.0
# 9758     tony       4    0-4       0.0

# %% [markdown]
# Here, we found NaN in the duplicated data. the amount of duplicated data we have is very minute in comparison to the total dataset we have. so we will drop all the duplicates, which will not affect our training.

# %%
#inplace is true since we dont need a new df
df.drop_duplicates(inplace =True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# password    1
# length      0
# bucket      0
# strength    5
# dtype: int64

# %%
#ensuring there are no empty passwords in df
df=df[df['password'].str.len() > 0].copy()

#copy() is used to work in same df, else separate df is formed

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 299972 entries, 0 to 299999
# Data columns (total 4 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   password  299972 non-null  object
#  1   length    299972 non-null  int64
#  2   bucket    299972 non-null  object
#  3   strength  299967 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 11.4+ MB

# %%
#dropping NaN password and strength found previously
df=df.dropna(subset=['password'])

# %%
df=df.dropna(subset=['strength'])

# %%
#checking for NaN again
df.isnull().sum()
# Out:
# password    0
# length      0
# bucket      0
# strength    0
# dtype: int64

# %% [markdown]
# # cleaaning unredeable characters

# %%
mask_unreadable = df['password'].str.contains(r'[^\x20-\x7E]', na=False)
mask_unreadable.sum()
# Out:
# 584

# %%
#checking the type of values we found
df[mask_unreadable].tail(50)
# Out:
#                                                 password  length bucket  \
# 298392                              à¸à¸-à¸ à¸à¸ /à¸à¹à¸      20    17+
# 298410                    à¸/-à¸¸à¸à¸à¸¶à¸à¸¶à¸à¸¸à¸à¹à¸      30    17+
# 298412                          à¸¢à¸à¸³à¸à¸à¸²à¸·à¸µà¸·      24    17+
# 298458                              à¸¢à¸¸à¸à¸ /à¸ à¸à¸¸      20    17+
# 298472                             à¸à¸ à¸à¸à¸à¸à¸¶à¸à¸¶      21    17+
# 298565                            à¸£à¸ªà¸à¸­à¸³à¸ªà¸³à¸      22    17+
# 298582                         05377178831komikazebarÄ±s      25    17+
# 298683                     à¸ªà¸à¸­à¸³à¸à¸µà¸à¸à¸·à¸ªà¸±      29    17+
# 298686  Ã²Ã²Ã²Ã²Ã²Ã²Ã²Ã²Ã²Ã²Ã²Ã²Ã²Ã²Ã²Ã²Ã²Ã²Ã²Ã²Ã²Ã²Ã²Ã²      48    17+
# 298717                                miamammaÃ¨isterica      18    17+
# 298721                              à¹à¸à¸à¸³à¸±-à¸à¸«à¸      20    17+
# 298728                                 elhombrequearaÃ±a      17    17+
# 298799                              à¸·à¸à¸·à¹à¸ªà¸³à¸²1      20    17+
# 298884                    à¹à¸à¸à¹à¹à¸¤à¸©à¹à¸ºÂ£$%^&*()      30    17+
# 298927                           à¸à¸à¸¶à¸¸à¸à¸¶à¸ à¸à¸/      23    17+
# 298955                                 à¹à¸à¸´à¹à¸ à¸à¸¶      17    17+
# 298971                    à¸à¹à¸­à¸¢à¸«à¸à¹à¸²0802874125      30    17+
# 298981                             à¸à¸à¸//à¸ à¸à¸ à¸¶à¸      21    17+
# 299054       à¸·à¸£à¸·à¹à¸9999à¹à¹à¸à¸°à¸à¸à¸£à¸ª.à¹à¸à¸      43    17+
# 299161                            à¸à¸à¸ à¸ /à¸¸à¸à¹à¸à¸      22    17+
# 299202                       à¹à¸­à¸¢à¹à¹à¹à¸à¸·à¸£à¸à¸2      27    17+
# 299206                          à¸¢à¸³à¸³à¸à¸·à¸µà¸°2261      24    17+
# 299212                        kÃ¼brabaycelebi2006und2007      26    17+
# 299227                              à¸à¸±à¸à¸£à¸±à¸à¸à¸³      20    17+
# 299240                    à¸·à¸à¸·à¸ªà¸à¸­à¸³à¸·à¸£à¸·à¹      30    17+
# 299269                      à¹à¸à¸·à¸°à¸à¸ªà¸à¸µà¸¢28082      28    17+
# 299310                                BERFÄ°N.ELÄ°F.1994      18    17+
# 299315                             à¸à¸à¸à¸à¹-à¸à¸à¸ à¸¶      21    17+
# 299378                                 Ð¼Ð¹ÑÐ¾ÑÑÐ¼Ð¹Ð»Ð»      17    17+
# 299458                         Ø©Ø®ÙØºØ©Ø´Ù_Ø©Ø®ÙØºØ©Ø´Ù      25    17+
# 299518                               à¹à¹à¸¹à¸¹à¹+à¹++à¹      19    17+
# 299531                                 à¸«à¸à¸·à¸³à¸£à¸³      17    17+
# 299547                                à¹à¹à¸à¸à¸à¸336699      18    17+
# 299586              La PoesÃ­a y Periodismo SatÃ­rico en      36    17+
# 299607               à¸£à¸±à¸à¸à¸²à¸à¸²à¸à¸à¹à¸à¸µà¸¢à¸§      35    17+
# 299631                             Ø´ÙØ§ÙØ¹ÙÙØ´Ø§-372982      21    17+
# 299650                               Ä01822177412334143Â      19    17+
# 299692                               à¸ªà¸³à¸²0873007674      19    17+
# 299741                                à¸à¸à¸à¸-à¸à¸¶à¸--      18    17+
# 299743                               szÃ©kesfehÃ¡Ã©rvÃ¡r      19    17+
# 299764                         à¸¢à¸³à¸à¹à¹à¸²à¸à¸à¸£à¸·      25    17+
# 299809                                 à¸à¸à¹à¸ à¸à¸à¹à¸      17    17+
# 299850                             à¸³à¸·à¸³à¸à¹à¸±à¸°à¸      21    17+
# 299859                             à¸à¸¶à¸à¸à¸¶à¸¸à¹à¸à¹      21    17+
# 299882                            à¸ à¸¶-à¸à¸¸à¸à¹à¸à¸à¸      22    17+
# 299900                             qwertyuiopasdfghjklÃ±      21    17+
# 299928                            à¸à¸à¸ à¸¶à¸ à¸à¸//à¸¸      22    17+
# 299940                        à¸à¸¢à¸à¸ªà¹à¸à¸à¸à¸²à¸à¸2      26    17+
# 299948                             xx1998seraunnuevoaÃ±o      21    17+
# 299987                               à¸­à¸£à¸«à¸à¸ªà¸±13      19    17+
#
#         strength
# 298392       4.0
# 298410       4.0
# 298412       4.0
# 298458       4.0
# 298472       4.0
# 298565       4.0
# 298582       4.0
# 298683       4.0
# 298686       1.0
# 298717       4.0
# 298721       4.0
# 298728       4.0
# 298799       4.0
# 298884       4.0
# 298927       4.0
# 298955       4.0
# 298971       4.0
# 298981       4.0
# 299054       4.0
# 299161       4.0
# 299202       4.0
# 299206       4.0
# 299212       4.0
# 299227       4.0
# 299240       4.0
# 299269       4.0
# 299310       4.0
# 299315       4.0
# 299378       4.0
# 299458       4.0
# 299518       4.0
# 299531       4.0
# 299547       3.0
# 299586       4.0
# 299607       4.0
# 299631       4.0
# 299650       4.0
# 299692       4.0
# 299741       4.0
# 299743       4.0
# 299764       4.0
# 299809       4.0
# 299850       4.0
# 299859       4.0
# 299882       4.0
# 299900       3.0
# 299928       4.0
# 299940       4.0
# 299948       4.0
# 299987       4.0

# %% [markdown]
# here we can see that characters such as"â¬, Â¬, Ã¸" are corrupted. But some are unicode of languages such as thai, arabic etc. so we will try to only remove the corrupt passwords, since it will be difficult and unaccurate to guess the original form of them.

# %%
#we make a list of corrupted characters produced from UTF-8 to latin-1
corrupted_char = [    'Ã', 'Â', 'â', 'Å', 'Ä', 'Æ', 
    'Ø', 'Ö', 'Ô', 'Õ', 
    'Û', 'Ù', 'Ú', 'Ü', 'Ý', 'Ÿ',
    'þ', 'ÿ','Ã±', 'Ã¡', 'Ã©', 'Ã³', 'Ãº', 'Ã¼', 'Ã§', 'Ã¨',
    'Â±', 'Â¬', 'Â£', 'Â®', 'Â©', 'Â¢',
    'â™', 'âœ', 'â€“', 'â€',]

#~ is used to negate the value
mask =~df['password'].str.contains('|'.join(map(re.escape,corrupted_char)), na=False)

#saving in a separate df
df_clean=df[mask].copy()

# %%
#checking again
mask_unreadable_v2 = df_clean['password'].str.contains(r'[^\x20-\x7E]', na=False)
mask_unreadable_v2.sum()
# Out:
# 306

# %%
df_clean[mask_unreadable_v2]
# Out:
#                           password  length bucket  strength
# 2221                          à¹à¹       4    0-4       0.0
# 6274                          ××××       4    0-4       0.0
# 39658                     à¹/--/à¹       8    5-8       2.0
# 42111                      montaña       7    5-8       2.0
# 85437                       × ××¢×       6    5-8       1.0
# ...                            ...     ...    ...       ...
# 299859       à¸à¸¶à¸à¸à¸¶à¸¸à¹à¸à¹      21    17+       4.0
# 299882      à¸ à¸¶-à¸à¸¸à¸à¹à¸à¸à¸      22    17+       4.0
# 299928      à¸à¸à¸ à¸¶à¸ à¸à¸//à¸¸      22    17+       4.0
# 299940  à¸à¸¢à¸à¸ªà¹à¸à¸à¸à¸²à¸à¸2      26    17+       4.0
# 299987         à¸­à¸£à¸«à¸à¸ªà¸±13      19    17+       4.0
#
# [306 rows x 4 columns]

# %% [markdown]
# # filtering lengths above 50 since they are unrealistic

# %%
df_clean = df_clean[df_clean['length']<=50].copy()
df_clean
# Out:
#                     password  length bucket  strength
# 0                       agus       4    0-4       1.0
# 1                       roar       4    0-4       1.0
# 2                       malz       4    0-4       1.0
# 3                       cuba       4    0-4       1.0
# 4                       pcms       4    0-4       1.0
# ...                      ...     ...    ...       ...
# 299995     changepassword___      17    17+       3.0
# 299996    stupidmotherfucker      18    17+       2.0
# 299997     luistekelounresto      17    17+       4.0
# 299998  themontles@yahoo.com      20    17+       4.0
# 299999     secilandralph7497      17    17+       4.0
#
# [299661 rows x 4 columns]

# %% [markdown]
# # Addition of new features

# %% [markdown]
# for doing exploratary data analysis, we should begin with adding a few extra columns, which will help in our EDA, and understanding how strength has been added.

# %% [markdown]
# Addition of 11 new features will be done sequentially

# %%
import pandas as pd
import numpy as np
import re
import math

# %% [markdown]
# # adding character counts

# %%
#adding lowercase feature
df_clean["lowercase_count"]=df_clean["password"].str.count(r'[a-z]')

#counting uppercase characters
df_clean["uppercase_count"]=df_clean["password"].str.count(r'[A-Z]')

#counting special characters
df_clean["special_count"]=df_clean["password"].str.count(r'[^a-zA-Z0-9]')

#counting digits
df_clean["digit_count"]=df_clean["password"].str.count(r'[a-z]')

# %%
#checking new columns
df_clean
# Out:
#                     password  length bucket  strength  lowercase_count  \
# 0                       agus       4    0-4       1.0                4
# 1                       roar       4    0-4       1.0                4
# 2                       malz       4    0-4       1.0                4
# 3                       cuba       4    0-4       1.0                4
# 4                       pcms       4    0-4       1.0                4
# ...                      ...     ...    ...       ...              ...
# 299995     changepassword___      17    17+       3.0               14
# 299996    stupidmotherfucker      18    17+       2.0               18
# 299997     luistekelounresto      17    17+       4.0               17
# 299998  themontles@yahoo.com      20    17+       4.0               18
# 299999     secilandralph7497      17    17+       4.0               13
#
#         uppercase_count  special_count  digit_count
# 0                     0              0            4
# 1                     0              0            4
# 2                     0              0            4
# 3                     0              0            4
# 4                     0              0            4
# ...                 ...            ...          ...
# 299995                0              3           14
# 299996                0              0           18
# 299997                0              0           17
# 299998                0              2           18
# 299999                0              0           13
#
# [299661 rows x 8 columns]

# %%
df_clean['special_count'].value_counts()
# Out:
# special_count
# 0     275800
# 1      15277
# 2       5183
# 3       1881
# 4        693
# 5        172
# 6        151
# 7         71
# 8         59
# 9         31
# 18        30
# 20        26
# 19        25
# 10        23
# 22        21
# 15        21
# 12        20
# 21        19
# 16        18
# 17        17
# 13        16
# 23        16
# 14        14
# 11        12
# 25        10
# 24         9
# 26         7
# 29         5
# 27         5
# 30         5
# 31         4
# 35         4
# 33         4
# 32         2
# 28         2
# 47         1
# 41         1
# 37         1
# 44         1
# 46         1
# 34         1
# 38         1
# 39         1
# Name: count, dtype: int64

# %% [markdown]
# # adding flags, char_diversity and unique_chars

# %%
#if there are special characters, value is 1 else 0
df_clean["has_special"]=(df_clean['special_count']>0).astype(int)

#if there are digits,value is 1 else 0
df_clean["has_digit"]=(df_clean['digit_count']>0).astype(int)

df_clean
# Out:
#                     password  length bucket  strength  lowercase_count  \
# 0                       agus       4    0-4       1.0                4
# 1                       roar       4    0-4       1.0                4
# 2                       malz       4    0-4       1.0                4
# 3                       cuba       4    0-4       1.0                4
# 4                       pcms       4    0-4       1.0                4
# ...                      ...     ...    ...       ...              ...
# 299995     changepassword___      17    17+       3.0               14
# 299996    stupidmotherfucker      18    17+       2.0               18
# 299997     luistekelounresto      17    17+       4.0               17
# 299998  themontles@yahoo.com      20    17+       4.0               18
# 299999     secilandralph7497      17    17+       4.0               13
#
#         uppercase_count  special_count  digit_count  has_special  has_digit
# 0                     0              0            4            0          1
# 1                     0              0            4            0          1
# 2                     0              0            4            0          1
# 3                     0              0            4            0          1
# 4                     0              0            4            0          1
# ...                 ...            ...          ...          ...        ...
# 299995                0              3           14            1          1
# 299996                0              0           18            0          1
# 299997                0              0           17            0          1
# 299998                0              2           18            1          1
# 299999                0              0           13            0          1
#
# [299661 rows x 10 columns]

# %%
#unique_chars means the no. of unique values in a password
#for e.g. "a!122" has 4 unique values (a,!,1,2)

df_clean["unique_chars"] = df_clean['password'].apply(lambda x:len(set(x)))

#char_diversity combines lowercase,uppercase,digit and special chars
#if one of them is present, value of char_diversity increases

df_clean["char_diversity"]=(
    (df_clean['lowercase_count']>0).astype(int)+
    (df_clean['uppercase_count']>0).astype(int)+
    (df_clean['digit_count']>0).astype(int)+
    (df_clean['special_count']>0).astype(int)
)

# %%
df_clean
# Out:
#                     password  length bucket  strength  lowercase_count  \
# 0                       agus       4    0-4       1.0                4
# 1                       roar       4    0-4       1.0                4
# 2                       malz       4    0-4       1.0                4
# 3                       cuba       4    0-4       1.0                4
# 4                       pcms       4    0-4       1.0                4
# ...                      ...     ...    ...       ...              ...
# 299995     changepassword___      17    17+       3.0               14
# 299996    stupidmotherfucker      18    17+       2.0               18
# 299997     luistekelounresto      17    17+       4.0               17
# 299998  themontles@yahoo.com      20    17+       4.0               18
# 299999     secilandralph7497      17    17+       4.0               13
#
#         uppercase_count  special_count  digit_count  has_special  has_digit  \
# 0                     0              0            4            0          1
# 1                     0              0            4            0          1
# 2                     0              0            4            0          1
# 3                     0              0            4            0          1
# 4                     0              0            4            0          1
# ...                 ...            ...          ...          ...        ...
# 299995                0              3           14            1          1
# 299996                0              0           18            0          1
# 299997                0              0           17            0          1
# 299998                0              2           18            1          1
# 299999                0              0           13            0          1
#
#         unique_chars  char_diversity
# 0                  4               2
# 1                  3               2
# 2                  4               2
# 3                  4               2
# 4                  4               2
# ...              ...             ...
# 299995            13               3
# 299996            14               2
# 299997            10               2
# 299998            13               3
# 299999            14               2
#
# [299661 rows x 12 columns]

# %% [markdown]
# # adding entropy,maxm repeat sequence and sequential patterns with their functions

# %%
#functions

#for entropy
def pass_entropy(x):
    if not x:
        return 0
    #counting the frequency of unique characters
    freq = pd.Series(list(x)).value_counts()
    prob = freq/len(x)
    #shanon entropy formula
    return -np.sum(prob*np.log2(prob))

# for sequential patterns ( such as abc, qwerty)
def has_sequence(x):
    x_lower=x.lower()
    sequence = [
        'abcdefghijklmnopqrstuvwxyz',
        '0123456789',
        'qwertyuiopasdfghjklzxcvbnm'
    ]
    for seq in sequence:
        for i in range(len(seq) - 2):
            if seq[i:i+3] in x_lower:
                return 1
    return 0

#for maximum repeated character in a password
def max_repeated(x):
    if not x:
        return 0
    return max((len(m.group(0)) for m in re.finditer(r'(.)\1*', x)))

# %%
#entropy
df_clean["entropy"] = df_clean['password'].apply(pass_entropy)

#sequential patterns
df_clean['seq_letters'] = df_clean['password'].apply(has_sequence)

#maximum repeated character count in a password
df_clean['max_repeat'] = df_clean['password'].apply(max_repeated)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[43], line 2
#       1 #entropy
# ----> 2 df_clean["entropy"] = df_clean['password'].apply(pass_entropy)
#       4 #sequential patterns
#       5 df_clean['seq_letters'] = df_clean['password'].apply(has_sequence)
#
# File E:\python\anaconda\installed\Lib\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# File E:\python\anaconda\installed\Lib\site-packages\pandas\core\apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File E:\python\anaconda\installed\Lib\site-packages\pandas\core\apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File E:\python\anaconda\installed\Lib\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File E:\python\anaconda\installed\Lib\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[42], line 8, in pass_entropy(x)
#       6     return 0
#       7 #counting the frequency of unique characters
# ----> 8 freq = pd.Series(list(x)).value_counts()
#       9 prob = freq/len(x)
#      10 #shanon entropy formula
#
# File E:\python\anaconda\installed\Lib\site-packages\pandas\core\base.py:1010, in IndexOpsMixin.value_counts(self, normalize, sort, ascending, bins, dropna)
#     923 @final
#     924 def value_counts(
#     925     self,
#    (...)
#     930     dropna: bool = True,
#     931 ) -> Series:
#     932     """
#     933     Return a Series containing counts of unique values.
#     934
#    (...)
#    1008     Name: count, dtype: int64
#    1009     """
# -> 1010     return algorithms.value_counts_internal(
#    1011         self,
#    1012         sort=sort,
#    1013         ascending=ascending,
#    1014         normalize=normalize,
#    1015         bins=bins,
#    1016         dropna=dropna,
#    1017     )
#
# File E:\python\anaconda\installed\Lib\site-packages\pandas\core\algorithms.py:954, in value_counts_internal(values, sort, ascending, normalize, bins, dropna)
#     951         result = Series(counts, index=idx, name=name, copy=False)
#     953 if sort:
# --> 954     result = result.sort_values(ascending=ascending)
#     956 if normalize:
#     957     result = result / counts.sum()
#
# File E:\python\anaconda\installed\Lib\site-packages\pandas\core\series.py:3869, in Series.sort_values(self, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    3867 else:
#    3868     values_to_sort = self._values
# -> 3869 sorted_index = nargsort(values_to_sort, kind, bool(ascending), na_position)
#    3871 if is_range_indexer(sorted_index, len(sorted_index)):
#    3872     if inplace:
#
# File E:\python\anaconda\installed\Lib\site-packages\pandas\core\sorting.py:439, in nargsort(items, kind, ascending, na_position, key, mask)
#     437     non_nans = non_nans[::-1]
#     438     non_nan_idx = non_nan_idx[::-1]
# --> 439 indexer = non_nan_idx[non_nans.argsort(kind=kind)]
#     440 if not ascending:
#     441     indexer = indexer[::-1]
#
# KeyboardInterrupt:

# %%
df_clean

# %%
df_clean.to_csv(r"E:\major_project\dataset\datasets\password_features.csv")
