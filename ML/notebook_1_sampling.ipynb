# %% [markdown]
# # importing pandas

# %%
import pandas as pd

# %% [markdown]
# # loading rockyou.txt dataset

# %%
df = pd.read_table('E:/major_project/dataset/data/rockyou.txt',names=['password'],encoding='latin-1',header=None)

# %%
df
# Out:
#                password
# 0                123456
# 1                 12345
# 2             123456789
# 3              password
# 4              iloveyou
# ...                 ...
# 14344092       xCvBnM,
# ie168
# abygurl69
# a6_123
# 14344096  *7Â¡Vamos!
#
# [14344097 rows x 1 columns]

# %% [markdown]
# # brief overlook on the dataset

# %%
#the type fo data in the dataset.Only passwords have been extracted in this phase
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14344097 entries, 0 to 14344096
# Data columns (total 1 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   password  object
# dtypes: object(1)
# memory usage: 109.4+ MB

# %%
df.head()
# Out:
#     password
# 0     123456
# 1      12345
# 2  123456789
# 3   password
# 4   iloveyou

# %%
#last 5 values of the dataset
df.tail()
# Out:
#                password
# 14344092       xCvBnM,
# ie168
# abygurl69
# a6_123
# 14344096  *7Â¡Vamos!

# %% [raw]
# here, the passwords have some letters that cant be recognized by the system. So using afunction, the unredeable characters will be removed.
#
# the function for non printable characters is the integral part in ths function:
#
# \x00-\x1F is for ASCII control characters (such as TAB)
# \x7F is for DEL(the del button)
# \x80-\x9F is for extended control codes(such as ',',euro signs), depends on encoding
#
# also
# \x20-\x7E are printable ASCII characters such as letters(a,b,c,d)etc

# %%
import re

def clean_password(p):
    if not isinstance(p,str):
        return None
    #for non-printable characters
    p = re.sub(r'[\x00-\x1F\x7F-\x9F]','',p)
    #for whitespace stripping
    p=p.strip()
    #for empty strings
    return p if len(p)>0 else None

df['password']=df['password'].apply(clean_password)
df=df.dropna()

# %% [markdown]
# checking if the weird values have been removed

# %%
df.tail(20)
# Out:
#             password
# 14344077          no
# 14344078        maka
# 14344079      jupanu
# 14344080  ciocolatax
# 14344081    angelica
# 14344082        1990
# 14344083        1111
# 14344084        pepe
# 14344085    markinho
# 14344086        mara
# 14344087       54321
# 14344088        123d
# 14344089           7
# 14344090     1234567
# 14344091           1
# 14344092     xCvBnM,
# 14344093       ie168
# 14344094   abygurl69
# 14344095      a6_123
# 14344096  *7Â¡Vamos!

# %%
#missing values
df.isna().sum()
# Out:
# password    0
# dtype: int64

# %% [markdown]
# # sampling data

# %% [markdown]
# for sampling data, we need to sample with precision, so majority types of data will be included (length of the data). random sampling may exclude passwords with higher length or lower length. so to make it equal, we first check the length of each password, then add it to continuous intervals. after this, we can decide the number of samples per each interval, or bucket in this case.
# this also has to be done due to the nature of the rock you dataset, which has fewer long passwords, and more medium length passwords.

# %%
# adding a length column to sample passwords of different length accurately

df['length']=df['password'].astype(str).str.len()

# %%
#checking columnn
df
# Out:
#             password  length
# 0             123456       6
# 1              12345       5
# 2          123456789       9
# 3           password       8
# 4           iloveyou       8
# ...              ...     ...
# 14344092     xCvBnM,       7
# 14344093       ie168       5
# 14344094   abygurl69       9
# 14344095      a6_123       6
# 14344096  *7Â¡Vamos!      10
#
# [14344097 rows x 2 columns]

# %%
#creating length buckets

bins=[0,4,8,12,16,100]
labels=["0-4","5-8", "9-12", "13-16", "17+"]

df["bucket"]=pd.cut(df["length"],bins=bins, labels=labels, include_lowest=True)
df
# Out:
#             password  length bucket
# 0             123456       6    5-8
# 1              12345       5    5-8
# 2          123456789       9   9-12
# 3           password       8    5-8
# 4           iloveyou       8    5-8
# ...              ...     ...    ...
# 14344092     xCvBnM,       7    5-8
# 14344093       ie168       5    5-8
# 14344094   abygurl69       9   9-12
# 14344095      a6_123       6    5-8
# 14344096  *7Â¡Vamos!      10   9-12
#
# [14344097 rows x 3 columns]

# %%
#deciding the number of samples per interval
#creating a dictionary with required samples from each category to stimulate the rock you set
target_sizes={
    "0-4": 10000,
    "5-8": 140000,
    "9-12": 110000,
    "13-16": 30000,
    "17+": 10000
}

# %%
samples = []

for bucket, size in target_sizes.items():
    group = df[df["bucket"] == bucket]

    if len(group) >= size:
        samples.append(group.sample(size, random_state=42))
    else:
        samples.append(group)

sampled_df = pd.concat(samples).reset_index(drop=True)

# %%
sampled_df
# Out:
#                     password  length bucket
# 0                       agus       4    0-4
# 1                       roar       4    0-4
# 2                       malz       4    0-4
# 3                       cuba       4    0-4
# 4                       pcms       4    0-4
# ...                      ...     ...    ...
# 299995     changepassword___      17    17+
# 299996    stupidmotherfucker      18    17+
# 299997     luistekelounresto      17    17+
# 299998  themontles@yahoo.com      20    17+
# 299999     secilandralph7497      17    17+
#
# [300000 rows x 3 columns]

# %% [markdown]
# # adding strength label using zxcvbn

# %% [markdown]
# We will be now using a python library zxcvbn to add strength to each password we have sampled. Since the sampling we have done is 300k, we haved used another library know as tqdm to know the rate of progress.

# %%
pip install zxcvbn
# Out:
# Requirement already satisfied: zxcvbn in e:\python\anaconda\installed\lib\site-packages (4.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tqdm
# Out:
# Requirement already satisfied: tqdm in e:\python\anaconda\installed\lib\site-packages (4.66.4)
# Requirement already satisfied: colorama in c:\users\asus\appdata\roaming\python\python312\site-packages (from tqdm) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
from zxcvbn import zxcvbn
from tqdm import tqdm

# %%
tqdm.pandas()

def get_strength(password):
    try:
        result = zxcvbn(password)
        return result["score"]
    except:
        return None

sampled_df["strength"]=sampled_df["password"].progress_apply(get_strength)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████| 300000/300000 [02:42<00:00, 1848.58it/s]

# %%
sampled_df
# Out:
#                     password  length bucket  strength
# 0                       agus       4    0-4       1.0
# 1                       roar       4    0-4       1.0
# 2                       malz       4    0-4       1.0
# 3                       cuba       4    0-4       1.0
# 4                       pcms       4    0-4       1.0
# ...                      ...     ...    ...       ...
# 299995     changepassword___      17    17+       3.0
# 299996    stupidmotherfucker      18    17+       2.0
# 299997     luistekelounresto      17    17+       4.0
# 299998  themontles@yahoo.com      20    17+       4.0
# 299999     secilandralph7497      17    17+       4.0
#
# [300000 rows x 4 columns]

# %%
sampled_df["strength"].value_counts()
# Out:
# strength
# 1.0    102678
# 2.0     98216
# 3.0     63857
# 4.0     32454
# 0.0      2790
# Name: count, dtype: int64

# %% [markdown]
# # saving file as csv

# %%
sampled_df.to_csv(r"E:\major_project\dataset\sampled_df.csv",index=False)
